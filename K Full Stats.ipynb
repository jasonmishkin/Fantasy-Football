# %%
# Import scraping modules
from urllib.request import urlopen
from bs4 import BeautifulSoup


# Import data manipulation modules
import pandas as pd
import numpy as np
# Import data visualization modules
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# URL of page
url = 'https://www.fantasypros.com/nfl/stats/k.php?scoring=HALF&ownership=y'
# Open URL and pass to BeautifulSoup
html = urlopen(url)
stats_page = BeautifulSoup(html)

# %%
# Collect table headers
column_headers = stats_page.findAll('tr')[0]
column_headers = [i.getText() for i in column_headers.findAll('th')]

print(column_headers)
# Out:
# ['Rank', 'Player', 'FG', 'FGA', 'PCT', 'LG', '1-19', '20-29', '30-39', '40-49', '50+', 'XPT', 'XPA', 'G', ' FPTS', 'FPTS/G', 'OWN']

# %%
# Collect table rows
rows = stats_page.findAll('tr')[1:]
# Get stats from each row
k_stats = []
for i in range(len(rows)):
  k_stats.append([col.getText() for col in rows[i].findAll('td')])

# %%
df = pd.DataFrame(k_stats, columns=column_headers)
df
# Out:
#    Rank                   Player  FG FGA   PCT  LG 1-19 20-29 30-39 40-49 50+  \
# 0     1     Jason Sanders (MIA)   36  39  92.3  56    1     8     7    12   8
# 1     2      Younghoe Koo (ATL)   37  39  94.9  54    0    10    11     8   8
# 2     3        Tyler Bass (BUF)   28  34  82.4  58    1     9     6     8   4
# 3     4     Daniel Carlson (LV)   33  35  94.3  54    0    18     8     3   4
# 4     5     Greg Zuerlein (DAL)   34  41  82.9  59    1     5    13    12   3
# ..  ...                      ...  ..  ..   ...  ..  ...   ...   ...   ...  ..
# 77   78  Garrett Lindholm (ATL)    0   0     0   0    0     0     0     0   0
# 78   79     Connor Hughes (DAL)    0   0     0   0    0     0     0     0   0
# 79   80     Clint Stitser (WAS)    0   0     0   0    0     0     0     0   0
# 80   81     Brian Johnson (CHI)    0   0     0   0    0     0     0     0   0
# 81   82           Ty Long (LAC)    0   0     0   0    0     0     0     0   0
#
#    XPT XPA   G   FPTS FPTS/G    OWN
# 0   36  36  16  172.0   10.8  75.0%
# 1   33  36  15  168.0   11.2  97.0%
# 2   57  59  16  157.0    9.8  80.0%
# 3   45  47  16  155.0    9.7  17.0%
# 4   33  36  16  153.0    9.6  84.0%
# ..  ..  ..  ..    ...    ...    ...
# 77   0   0   0      0      0
# 78   0   0   0      0      0
# 79   0   0   0      0      0
# 80   0   0   0      0      0   0.0%
# 81   0   0  16   -2.8   -0.2   0.0%
#
# [82 rows x 17 columns]

# %%
df['Team'] = df['Player'].str[-6:]
position = 'K'
df['Pos'] = position
df.head()
# Out:
#   Rank                Player  FG FGA   PCT  LG 1-19 20-29 30-39 40-49 50+ XPT  \
# 0    1  Jason Sanders (MIA)   36  39  92.3  56    1     8     7    12   8  36
# 1    2   Younghoe Koo (ATL)   37  39  94.9  54    0    10    11     8   8  33
# 2    3     Tyler Bass (BUF)   28  34  82.4  58    1     9     6     8   4  57
# 3    4  Daniel Carlson (LV)   33  35  94.3  54    0    18     8     3   4  45
# 4    5  Greg Zuerlein (DAL)   34  41  82.9  59    1     5    13    12   3  33
#
#   XPA   G   FPTS FPTS/G    OWN    Team Pos
# 0  36  16  172.0   10.8  75.0%  (MIA)    K
# 1  36  15  168.0   11.2  97.0%  (ATL)    K
# 2  59  16  157.0    9.8  80.0%  (BUF)    K
# 3  47  16  155.0    9.7  17.0%   (LV)    K
# 4  36  16  153.0    9.6  84.0%  (DAL)    K

# %%
new_columns = df.columns.values
new_columns[-3] = 'Pct_Owned'
new_columns[-5] = 'Fantasy_Points'
new_columns[-4] = 'Fantasy_Points_Per_Game'
new_columns[-6] = 'Games'

df.columns = new_columns

df.head()
# Out:
#   Rank                Player  FG FGA   PCT  LG 1-19 20-29 30-39 40-49 50+ XPT  \
# 0    1  Jason Sanders (MIA)   36  39  92.3  56    1     8     7    12   8  36
# 1    2   Younghoe Koo (ATL)   37  39  94.9  54    0    10    11     8   8  33
# 2    3     Tyler Bass (BUF)   28  34  82.4  58    1     9     6     8   4  57
# 3    4  Daniel Carlson (LV)   33  35  94.3  54    0    18     8     3   4  45
# 4    5  Greg Zuerlein (DAL)   34  41  82.9  59    1     5    13    12   3  33
#
#   XPA Games Fantasy_Points Fantasy_Points_Per_Game Pct_Owned    Team Pos
# 0  36    16          172.0                    10.8     75.0%  (MIA)    K
# 1  36    15          168.0                    11.2     97.0%  (ATL)    K
# 2  59    16          157.0                     9.8     80.0%  (BUF)    K
# 3  47    16          155.0                     9.7     17.0%   (LV)    K
# 4  36    16          153.0                     9.6     84.0%  (DAL)    K

# %%
# Create data subset for radar chart
categories = ['Games','FG','FGA','PCT','LG','1-19','20-29','30-39','40-49','50+','XPT','XPA','Fantasy_Points','Fantasy_Points_Per_Game','Pct_Owned']
df1 = df[['Rank', 'Player','Team','Pos'] + categories]
df1.head()
# Out:
#   Rank                Player    Team Pos Games  FG FGA   PCT  LG 1-19 20-29  \
# 0    1  Jason Sanders (MIA)   (MIA)    K    16  36  39  92.3  56    1     8
# 1    2   Younghoe Koo (ATL)   (ATL)    K    15  37  39  94.9  54    0    10
# 2    3     Tyler Bass (BUF)   (BUF)    K    16  28  34  82.4  58    1     9
# 3    4  Daniel Carlson (LV)    (LV)    K    16  33  35  94.3  54    0    18
# 4    5  Greg Zuerlein (DAL)   (DAL)    K    16  34  41  82.9  59    1     5
#
#   30-39 40-49 50+ XPT XPA Fantasy_Points Fantasy_Points_Per_Game Pct_Owned
# 0     7    12   8  36  36          172.0                    10.8     75.0%
# 1    11     8   8  33  36          168.0                    11.2     97.0%
# 2     6     8   4  57  59          157.0                     9.8     80.0%
# 3     8     3   4  45  47          155.0                     9.7     17.0%
# 4    13    12   3  33  36          153.0                     9.6     84.0%

# %%
df1['Player'] = df1['Player'].str.slice(0, -6)
df1.head()
# Out:
#   Rank          Player    Team Pos Games  FG FGA   PCT  LG 1-19 20-29 30-39  \
# 0    1  Jason Sanders   (MIA)    K    16  36  39  92.3  56    1     8     7
# 1    2   Younghoe Koo   (ATL)    K    15  37  39  94.9  54    0    10    11
# 2    3     Tyler Bass   (BUF)    K    16  28  34  82.4  58    1     9     6
# 3    4  Daniel Carlson   (LV)    K    16  33  35  94.3  54    0    18     8
# 4    5  Greg Zuerlein   (DAL)    K    16  34  41  82.9  59    1     5    13
#
#   40-49 50+ XPT XPA Fantasy_Points Fantasy_Points_Per_Game Pct_Owned
# 0    12   8  36  36          172.0                    10.8     75.0%
# 1     8   8  33  36          168.0                    11.2     97.0%
# 2     8   4  57  59          157.0                     9.8     80.0%
# 3     3   4  45  47          155.0                     9.7     17.0%
# 4    12   3  33  36          153.0                     9.6     84.0%

# %%
ints = ['Games','FG','FGA','LG','1-19','20-29','30-39','40-49','50+','XPT','XPA']
floats = ['PCT','Fantasy_Points','Fantasy_Points_Per_Game',]
df1['Games'] = df1['Games'].astype('int64')

for i in ints:
    df1[i] = df1[i].astype('int64')

for i in floats:
    df1[i] = df1[i].astype('float64')

# %%
df1.dtypes
# Out:
# Rank                        object
# Player                      object
# Team                        object
# Pos                         object
# Games                        int64
# FG                           int64
# FGA                          int64
# PCT                        float64
# LG                           int64
# 1-19                         int64
# 20-29                        int64
# 30-39                        int64
# 40-49                        int64
# 50+                          int64
# XPT                          int64
# XPA                          int64
# Fantasy_Points             float64
# Fantasy_Points_Per_Game    float64
# Pct_Owned                   object
# dtype: object

# %%
df1
# Out:
#    Rank             Player    Team Pos  Games  FG  FGA   PCT  LG  1-19  20-29  \
# 0     1     Jason Sanders   (MIA)    K     16  36   39  92.3  56     1      8
# 1     2      Younghoe Koo   (ATL)    K     15  37   39  94.9  54     0     10
# 2     3        Tyler Bass   (BUF)    K     16  28   34  82.4  58     1      9
# 3     4     Daniel Carlson   (LV)    K     16  33   35  94.3  54     0     18
# 4     5     Greg Zuerlein   (DAL)    K     16  34   41  82.9  59     1      5
# ..  ...                ...     ...  ..    ...  ..  ...   ...  ..   ...    ...
# 77   78  Garrett Lindholm   (ATL)    K      0   0    0   0.0   0     0      0
# 78   79     Connor Hughes   (DAL)    K      0   0    0   0.0   0     0      0
# 79   80     Clint Stitser   (WAS)    K      0   0    0   0.0   0     0      0
# 80   81     Brian Johnson   (CHI)    K      0   0    0   0.0   0     0      0
# 81   82           Ty Long   (LAC)    K     16   0    0   0.0   0     0      0
#
#     30-39  40-49  50+  XPT  XPA  Fantasy_Points  Fantasy_Points_Per_Game  \
# 0       7     12    8   36   36           172.0                     10.8
# 1      11      8    8   33   36           168.0                     11.2
# 2       6      8    4   57   59           157.0                      9.8
# 3       8      3    4   45   47           155.0                      9.7
# 4      13     12    3   33   36           153.0                      9.6
# ..    ...    ...  ...  ...  ...             ...                      ...
# 77      0      0    0    0    0             0.0                      0.0
# 78      0      0    0    0    0             0.0                      0.0
# 79      0      0    0    0    0             0.0                      0.0
# 80      0      0    0    0    0             0.0                      0.0
# 81      0      0    0    0    0            -2.8                     -0.2
#
#    Pct_Owned
# 0      75.0%
# 1      97.0%
# 2      80.0%
# 3      17.0%
# 4      84.0%
# ..       ...
# 77
# 78
# 79
# 80      0.0%
# 81      0.0%
#
# [82 rows x 19 columns]

# %%
df1.to_csv('Kstats.csv',index=False)

# %%
# URL of page
url = 'https://www.cbssports.com/fantasy/football/draft/averages/both/h2h/K/'
# Open URL and pass to BeautifulSoup
html = urlopen(url)
stats_page = BeautifulSoup(html)

# %%
# Collect table headers
column_headers = stats_page.findAll('tr')[0]
column_headers = [i.getText() for i in column_headers.findAll('th')]

print(column_headers)
# Out:
# ['\n                \n                                    Rank\n                \n                            ', '\n                \n                                    Player\n                \n                            ', '\n                \n                                    Trend\n                \n                            ', '\n                \n                                    Avg Pos\n                \n                            ', '\n                \n                                    Hi/Lo\n                \n                            ', '\n                \n                                    Pct\n                \n                            ']

# %%
# Collect table rows
rows = stats_page.findAll('tr')[1:]
# Get stats from each row
k_stats = []
for i in range(len(rows)):
    k_stats.append([col.getText() for col in rows[i].findAll('td')])
    #rb_stats.strip('\n')

# %%
df1 = pd.DataFrame(k_stats, columns=column_headers)
df1
# Out:
#    \n                \n                                    Rank\n                \n                              \
# 0         \n                    111\n
# 1         \n                    120\n
# 2         \n                    135\n
# 3         \n                    156\n
# 4         \n                    162\n
# 5         \n                    166\n
# 6         \n                    175\n
# 7         \n                    187\n
# 8         \n                    201\n
# 9         \n                    202\n
# 10        \n                    204\n
# 11        \n                    215\n
# 12        \n                    218\n
# 13        \n                    220\n
# 14        \n                    221\n
# 15        \n                    222\n
# 16        \n                    223\n
# 17        \n                    224\n
#
#    \n                \n                                    Player\n                \n                              \
# 0   \n\n\nJ. Tucker\n\n                        K\n...
# 1   \n\n\nH. Butker\n\n                        K\n...
# 2   \n\n\nG. Zuerlein\n\n                        K...
# 3   \n\n\nY. Koo\n\n                        K\n   ...
# 4   \n\n\nT. Bass\n\n                        K\n  ...
# 5   \n\n\nR. Succop\n\n                        K\n...
# 6   \n\n\nJ. Sanders\n\n                        K\...
# 7   \n\n\nR. Blankenship\n\n                      ...
# 8   \n\n\nB. McManus\n\n                        K\...
# 9   \n\n\nM. Crosby\n\n                        K\n...
# 10  \n\n\nR. Gould\n\n                        K\n ...
# 11  \n\n\nM. Prater\n\n                        K\n...
# 12  \n\n\nJ. Myers\n\n                        K\n ...
# 13  \n\n\nM. Gay\n\n                        K\n   ...
# 14  \n\n\nD. Carlson\n\n                        K\...
# 15  \n\n\nC. Boswell\n\n                        K\...
# 16  \n\n\nM. Badgley\n\n                        K\...
# 17  \n\n\nC. Santos\n\n                        K\n...
#
#    \n                \n                                    Trend\n                \n                              \
# 0                                         \n\n 12\n\n
# 1                                         \n\n -8\n\n
# 2                                          \n\n 2\n\n
# 3                                          \n\n 1\n\n
# 4                                          \n\n 1\n\n
# 5                                        \n\n -11\n\n
# 6                                          \n\n 2\n\n
# 7                                          \n\n 5\n\n
# 8                                         \n\n 23\n\n
# 9                                          \n\n 7\n\n
# 10                                       \n\n -19\n\n
# 11                                         \n\n 4\n\n
# 12                                         \n\n 2\n\n
# 13                                         \n\n 1\n\n
# 14                                         \n\n 4\n\n
# 15          \n                    —\n
# 16                                         \n\n 4\n\n
# 17                                        \n\n -1\n\n
#
#    \n                \n                                    Avg Pos\n                \n                              \
# 0      \n                    114.53\n
# 1      \n                    117.42\n
# 2      \n                    130.44\n
# 3      \n                    138.92\n
# 4      \n                    142.04\n
# 5      \n                    145.38\n
# 6      \n                    149.15\n
# 7      \n                    154.02\n
# 8      \n                    162.23\n
# 9      \n                    162.28\n
# 10     \n                    162.46\n
# 11     \n                    167.53\n
# 12     \n                    169.67\n
# 13     \n                    171.28\n
# 14     \n                    172.29\n
# 15     \n                    172.47\n
# 16     \n                    174.25\n
# 17     \n                    175.37\n
#
#    \n                \n                                    Hi/Lo\n                \n                              \
# 0      \n                    68/162\n
# 1      \n                    72/163\n
# 2      \n                    73/183\n
# 3      \n                    90/184\n
# 4      \n                    92/188\n
# 5      \n                    93/194\n
# 6     \n                    100/194\n
# 7     \n                    105/198\n
# 8     \n                    112/210\n
# 9     \n                    109/213\n
# 10    \n                    113/210\n
# 11    \n                    122/215\n
# 12    \n                    120/217\n
# 13    \n                    124/218\n
# 14    \n                    127/222\n
# 15    \n                    120/226\n
# 16    \n                    127/225\n
# 17    \n                    126/231\n
#
#    \n                \n                                    Pct\n                \n
# 0        \n                    95.6\n
# 1        \n                    95.7\n
# 2        \n                    94.3\n
# 3        \n                    94.6\n
# 4        \n                    94.2\n
# 5        \n                    91.0\n
# 6        \n                    91.0\n
# 7        \n                    88.3\n
# 8        \n                    61.1\n
# 9        \n                    56.3\n
# 10       \n                    70.4\n
# 11       \n                    50.8\n
# 12       \n                    37.6\n
# 13       \n                    36.4\n
# 14       \n                    40.1\n
# 15       \n                    22.0\n
# 16       \n                    31.2\n
# 17       \n                    22.7\n

# %%
df1 = df1.replace(r'\n',' ', regex=True)

# %%
df1
# Out:
#    \n                \n                                    Rank\n                \n                              \
# 0                                111
# 1                                120
# 2                                135
# 3                                156
# 4                                162
# 5                                166
# 6                                175
# 7                                187
# 8                                201
# 9                                202
# 10                               204
# 11                               215
# 12                               218
# 13                               220
# 14                               221
# 15                               222
# 16                               223
# 17                               224
#
#    \n                \n                                    Player\n                \n                              \
# 0      J. Tucker                          K       ...
# 1      H. Butker                          K       ...
# 2      G. Zuerlein                          K     ...
# 3      Y. Koo                          K          ...
# 4      T. Bass                          K         ...
# 5      R. Succop                          K       ...
# 6      J. Sanders                          K      ...
# 7      R. Blankenship                          K  ...
# 8      B. McManus                          K      ...
# 9      M. Crosby                          K       ...
# 10     R. Gould                          K        ...
# 11     M. Prater                          K       ...
# 12     J. Myers                          K        ...
# 13     M. Gay                          K          ...
# 14     D. Carlson                          K      ...
# 15     C. Boswell                          K      ...
# 16     M. Badgley                          K      ...
# 17     C. Santos                          K       ...
#
#    \n                \n                                    Trend\n                \n                              \
# 0                                                12
# 1                                                -8
# 2                                                 2
# 3                                                 1
# 4                                                 1
# 5                                               -11
# 6                                                 2
# 7                                                 5
# 8                                                23
# 9                                                 7
# 10                                              -19
# 11                                                4
# 12                                                2
# 13                                                1
# 14                                                4
# 15                                 —
# 16                                                4
# 17                                               -1
#
#    \n                \n                                    Avg Pos\n                \n                              \
# 0                             114.53
# 1                             117.42
# 2                             130.44
# 3                             138.92
# 4                             142.04
# 5                             145.38
# 6                             149.15
# 7                             154.02
# 8                             162.23
# 9                             162.28
# 10                            162.46
# 11                            167.53
# 12                            169.67
# 13                            171.28
# 14                            172.29
# 15                            172.47
# 16                            174.25
# 17                            175.37
#
#    \n                \n                                    Hi/Lo\n                \n                              \
# 0                             68/162
# 1                             72/163
# 2                             73/183
# 3                             90/184
# 4                             92/188
# 5                             93/194
# 6                            100/194
# 7                            105/198
# 8                            112/210
# 9                            109/213
# 10                           113/210
# 11                           122/215
# 12                           120/217
# 13                           124/218
# 14                           127/222
# 15                           120/226
# 16                           127/225
# 17                           126/231
#
#    \n                \n                                    Pct\n                \n
# 0                               95.6
# 1                               95.7
# 2                               94.3
# 3                               94.6
# 4                               94.2
# 5                               91.0
# 6                               91.0
# 7                               88.3
# 8                               61.1
# 9                               56.3
# 10                              70.4
# 11                              50.8
# 12                              37.6
# 13                              36.4
# 14                              40.1
# 15                              22.0
# 16                              31.2
# 17                              22.7

# %%
df1.to_csv('Kadpstats.csv',index=False)
