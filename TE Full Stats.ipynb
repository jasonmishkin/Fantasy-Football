# %%
# Import scraping modules
from urllib.request import urlopen
from bs4 import BeautifulSoup


# Import data manipulation modules
import pandas as pd
import numpy as np
# Import data visualization modules
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# URL of page
url = 'https://www.fantasypros.com/nfl/stats/te.php?scoring=HALF&ownership=y'
# Open URL and pass to BeautifulSoup
html = urlopen(url)
stats_page = BeautifulSoup(html)

# %%
# Collect table headers
column_headers = stats_page.findAll('tr')[1]
column_headers = [i.getText() for i in column_headers.findAll('th')]

print(column_headers)
# Out:
# ['Rank', 'Player', 'REC', 'TGT', 'YDS', 'Y/R', 'LG', '20+', 'TD', 'ATT', 'YDS', 'TD', 'FL', 'G', ' FPTS', 'FPTS/G', 'OWN']

# %%
# Collect table rows
rows = stats_page.findAll('tr')[2:]
# Get stats from each row
te_stats = []
for i in range(len(rows)):
  te_stats.append([col.getText() for col in rows[i].findAll('td')])

# %%
df = pd.DataFrame(te_stats, columns=column_headers)
df
# Out:
#     Rank                  Player  REC  TGT    YDS   Y/R  LG 20+  TD ATT YDS  \
# 0      1      Travis Kelce (KC)   105  145  1,416  13.5  45   0  11   0   0
# 1      2     Darren Waller (LV)   107  145  1,196  11.2  38   0   9   0   0
# 2      3     Robert Tonyan (GB)    52   59    586  11.3  45   0  11   0   0
# 3      4   T.J. Hockenson (DET)    67  101    723  10.8  51   0   6   1   0
# 4      5     Mark Andrews (BAL)    58   88    701  12.1  39   0   7   0   0
# ..   ...                     ...  ...  ...    ...   ...  ..  ..  ..  ..  ..
# 258  259        Khari Lee (DET)     0    0      0     0   0   0   0   0   0
# 259  260  Kelvin Benjamin (NYG)     0    0      0     0   0   0   0   0   0
# 260  261   Xavier Grimble (BAL)     0    0      0     0   0   0   0   0   0
# 261  262       Kyle Nelson (FA)     0    0      0     0   0   0   0   0   0
# 262  263         Noah Grey (KC)     0    0      0     0   0   0   0   0   0
#
#     TD FL   G   FPTS FPTS/G     OWN
# 0    0  1  15  260.3   17.4  100.0%
# 1    0  2  16  225.1   14.1  100.0%
# 2    0  0  16  150.6    9.4   91.0%
# 3    0  1  16  141.8    8.9   99.0%
# 4    0  0  14  141.1   10.1   99.0%
# ..  .. ..  ..    ...    ...     ...
# 258  0  0   0      0      0    0.0%
# 259  0  0   0      0      0    0.0%
# 260  0  0   0      0      0    0.0%
# 261  0  0   3    0.0    0.0    0.0%
# 262  0  0   0      0      0
#
# [263 rows x 17 columns]

# %%
df['Team'] = df['Player'].str[-6:]
position = 'TE'

df['Pos'] = position
df.head()
# Out:
#   Rank                 Player  REC  TGT    YDS   Y/R  LG 20+  TD ATT YDS TD  \
# 0    1     Travis Kelce (KC)   105  145  1,416  13.5  45   0  11   0   0  0
# 1    2    Darren Waller (LV)   107  145  1,196  11.2  38   0   9   0   0  0
# 2    3    Robert Tonyan (GB)    52   59    586  11.3  45   0  11   0   0  0
# 3    4  T.J. Hockenson (DET)    67  101    723  10.8  51   0   6   1   0  0
# 4    5    Mark Andrews (BAL)    58   88    701  12.1  39   0   7   0   0  0
#
#   FL   G   FPTS FPTS/G     OWN    Team Pos
# 0  1  15  260.3   17.4  100.0%   (KC)   TE
# 1  2  16  225.1   14.1  100.0%   (LV)   TE
# 2  0  16  150.6    9.4   91.0%   (GB)   TE
# 3  1  16  141.8    8.9   99.0%  (DET)   TE
# 4  0  14  141.1   10.1   99.0%  (BAL)   TE

# %%
new_columns = df.columns.values
new_columns[-3] = 'Pct Owned'
new_columns[-5] = 'Fantasy Points'
new_columns[-4] = 'Fantasy Points Per Game'
new_columns[-11] = 'Rec TD'
new_columns[-7] = 'Fumbles Lost'
new_columns[-6] = 'Games'
new_columns[4] = 'Rec YDS'
new_columns[-10] = 'Rush ATT'
new_columns[-8] = 'Rush TD'
new_columns[-9] = 'Rush YDS'
df.columns = new_columns

df.head()
# Out:
#   Rank                 Player  REC  TGT Rec YDS   Y/R  LG 20+ Rec TD Rush ATT  \
# 0    1     Travis Kelce (KC)   105  145   1,416  13.5  45   0     11        0
# 1    2    Darren Waller (LV)   107  145   1,196  11.2  38   0      9        0
# 2    3    Robert Tonyan (GB)    52   59     586  11.3  45   0     11        0
# 3    4  T.J. Hockenson (DET)    67  101     723  10.8  51   0      6        1
# 4    5    Mark Andrews (BAL)    58   88     701  12.1  39   0      7        0
#
#   Rush YDS Rush TD Fumbles Lost Games Fantasy Points Fantasy Points Per Game  \
# 0        0       0            1    15          260.3                    17.4
# 1        0       0            2    16          225.1                    14.1
# 2        0       0            0    16          150.6                     9.4
# 3        0       0            1    16          141.8                     8.9
# 4        0       0            0    14          141.1                    10.1
#
#   Pct Owned    Team Pos
# 0    100.0%   (KC)   TE
# 1    100.0%   (LV)   TE
# 2     91.0%   (GB)   TE
# 3     99.0%  (DET)   TE
# 4     99.0%  (BAL)   TE

# %%
# Create data subset for radar chart
categories = ['Games','REC','TGT','Rec YDS','Y/R','LG','Rec TD','Rush ATT','Rush YDS','Rush TD','Fumbles Lost','Fantasy Points','Fantasy Points Per Game','Pct Owned']
df1 = df[['Rank', 'Player','Team','Pos'] + categories]
df1.head()
# Out:
#   Rank                 Player    Team Pos Games  REC  TGT Rec YDS   Y/R  LG  \
# 0    1     Travis Kelce (KC)    (KC)   TE    15  105  145   1,416  13.5  45
# 1    2    Darren Waller (LV)    (LV)   TE    16  107  145   1,196  11.2  38
# 2    3    Robert Tonyan (GB)    (GB)   TE    16   52   59     586  11.3  45
# 3    4  T.J. Hockenson (DET)   (DET)   TE    16   67  101     723  10.8  51
# 4    5    Mark Andrews (BAL)   (BAL)   TE    14   58   88     701  12.1  39
#
#   Rec TD Rush ATT Rush YDS Rush TD Fumbles Lost Fantasy Points  \
# 0     11        0        0       0            1          260.3
# 1      9        0        0       0            2          225.1
# 2     11        0        0       0            0          150.6
# 3      6        1        0       0            1          141.8
# 4      7        0        0       0            0          141.1
#
#   Fantasy Points Per Game Pct Owned
# 0                    17.4    100.0%
# 1                    14.1    100.0%
# 2                     9.4     91.0%
# 3                     8.9     99.0%
# 4                    10.1     99.0%

# %%
df1['Player'] = df1['Player'].str.slice(0, -6)
df1.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   Rank           Player    Team Pos Games  REC  TGT Rec YDS   Y/R  LG Rec TD  \
# 0    1     Travis Kelce   (KC)   TE    15  105  145   1,416  13.5  45     11
# 1    2    Darren Waller   (LV)   TE    16  107  145   1,196  11.2  38      9
# 2    3    Robert Tonyan   (GB)   TE    16   52   59     586  11.3  45     11
# 3    4  T.J. Hockenson   (DET)   TE    16   67  101     723  10.8  51      6
# 4    5    Mark Andrews   (BAL)   TE    14   58   88     701  12.1  39      7
#
#   Rush ATT Rush YDS Rush TD Fumbles Lost Fantasy Points  \
# 0        0        0       0            1          260.3
# 1        0        0       0            2          225.1
# 2        0        0       0            0          150.6
# 3        1        0       0            1          141.8
# 4        0        0       0            0          141.1
#
#   Fantasy Points Per Game Pct Owned
# 0                    17.4    100.0%
# 1                    14.1    100.0%
# 2                     9.4     91.0%
# 3                     8.9     99.0%
# 4                    10.1     99.0%

# %%
df1['Rec YDS'] = df1['Rec YDS'].str.replace(',', '')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ints = ['Games','Rush ATT','Rush YDS','LG','Rush TD','REC','TGT','Rec YDS','Rec TD','Fumbles Lost']
floats = ['Y/R','Fantasy Points','Fantasy Points Per Game',]
df1['Games'] = df1['Games'].astype('int64')

for i in ints:
    df1[i] = df1[i].astype('int64')

for i in floats:
    df1[i] = df1[i].astype('float64')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df1.dtypes
# Out:
# Rank                        object
# Player                      object
# Team                        object
# Pos                         object
# Games                        int64
# REC                          int64
# TGT                          int64
# Rec YDS                      int64
# Y/R                        float64
# LG                           int64
# Rec TD                       int64
# Rush ATT                     int64
# Rush YDS                     int64
# Rush TD                      int64
# Fumbles Lost                 int64
# Fantasy Points             float64
# Fantasy Points Per Game    float64
# Pct Owned                   object
# dtype: object

# %%
df1
# Out:
#     Rank            Player    Team Pos  Games  REC  TGT  Rec YDS   Y/R  LG  \
# 0      1      Travis Kelce   (KC)   TE     15  105  145     1416  13.5  45
# 1      2     Darren Waller   (LV)   TE     16  107  145     1196  11.2  38
# 2      3     Robert Tonyan   (GB)   TE     16   52   59      586  11.3  45
# 3      4   T.J. Hockenson   (DET)   TE     16   67  101      723  10.8  51
# 4      5     Mark Andrews   (BAL)   TE     14   58   88      701  12.1  39
# ..   ...               ...     ...  ..    ...  ...  ...      ...   ...  ..
# 258  259        Khari Lee   (DET)   TE      0    0    0        0   0.0   0
# 259  260  Kelvin Benjamin   (NYG)   TE      0    0    0        0   0.0   0
# 260  261   Xavier Grimble   (BAL)   TE      0    0    0        0   0.0   0
# 261  262       Kyle Nelson   (FA)   TE      3    0    0        0   0.0   0
# 262  263         Noah Grey   (KC)   TE      0    0    0        0   0.0   0
#
#      Rec TD  Rush ATT  Rush YDS  Rush TD  Fumbles Lost  Fantasy Points  \
# 0        11         0         0        0             1           260.3
# 1         9         0         0        0             2           225.1
# 2        11         0         0        0             0           150.6
# 3         6         1         0        0             1           141.8
# 4         7         0         0        0             0           141.1
# ..      ...       ...       ...      ...           ...             ...
# 258       0         0         0        0             0             0.0
# 259       0         0         0        0             0             0.0
# 260       0         0         0        0             0             0.0
# 261       0         0         0        0             0             0.0
# 262       0         0         0        0             0             0.0
#
#      Fantasy Points Per Game Pct Owned
# 0                       17.4    100.0%
# 1                       14.1    100.0%
# 2                        9.4     91.0%
# 3                        8.9     99.0%
# 4                       10.1     99.0%
# ..                       ...       ...
# 258                      0.0      0.0%
# 259                      0.0      0.0%
# 260                      0.0      0.0%
# 261                      0.0      0.0%
# 262                      0.0
#
# [263 rows x 18 columns]

# %%
df1.to_csv('TEstats.csv',index=False)

# %%
# URL of page
url = 'https://www.cbssports.com/fantasy/football/draft/averages/both/h2h/TE/'
# Open URL and pass to BeautifulSoup
html = urlopen(url)
stats_page = BeautifulSoup(html)

# %%
# Collect table headers
column_headers = stats_page.findAll('tr')[0]
column_headers = [i.getText() for i in column_headers.findAll('th')]

print(column_headers)
# Out:
# ['\n                \n                                    Rank\n                \n                            ', '\n                \n                                    Player\n                \n                            ', '\n                \n                                    Trend\n                \n                            ', '\n                \n                                    Avg Pos\n                \n                            ', '\n                \n                                    Hi/Lo\n                \n                            ', '\n                \n                                    Pct\n                \n                            ']

# %%
# Collect table rows
rows = stats_page.findAll('tr')[1:]
# Get stats from each row
te_stats = []
for i in range(len(rows)):
    te_stats.append([col.getText() for col in rows[i].findAll('td')])
    #rb_stats.strip('\n')

# %%
df1 = pd.DataFrame(te_stats, columns=column_headers)
df1
# Out:
#    \n                \n                                    Rank\n                \n                              \
# 0           \n                    8\n
# 1          \n                    23\n
# 2          \n                    25\n
# 3          \n                    53\n
# 4          \n                    55\n
# 5          \n                    66\n
# 6          \n                    79\n
# 7          \n                    85\n
# 8          \n                    98\n
# 9          \n                    99\n
# 10        \n                    100\n
# 11        \n                    104\n
# 12        \n                    121\n
# 13        \n                    126\n
# 14        \n                    130\n
# 15        \n                    142\n
# 16        \n                    160\n
# 17        \n                    176\n
# 18        \n                    180\n
# 19        \n                    181\n
# 20        \n                    185\n
# 21        \n                    193\n
# 22        \n                    200\n
# 23        \n                    212\n
# 24        \n                    217\n
#
#    \n                \n                                    Player\n                \n                              \
# 0   \n\n\nT. Kelce\n\n                        TE\n...
# 1   \n\n\nG. Kittle\n\n                        TE\...
# 2   \n\n\nD. Waller\n\n                        TE\...
# 3   \n\n\nM. Andrews\n\n                        TE...
# 4   \n\n\nK. Pitts\n\n                        TE\n...
# 5   \n\n\nT. Hockenson\n\n                        ...
# 6   \n\n\nL. Thomas\n\n                        TE\...
# 7   \n\n\nN. Fant\n\n                        TE\n ...
# 8   \n\n\nD. Goedert\n\n                        TE...
# 9   \n\n\nT. Higbee\n\n                        TE\...
# 10  \n\n\nM. Gesicki\n\n                        TE...
# 11  \n\n\nR. Tonyan\n\n                        TE\...
# 12  \n\n\nI. Smith\n\n                        TE\n...
# 13  \n\n\nR. Gronkowski\n\n                       ...
# 14  \n\n\nJ. Cook\n\n                        TE\n ...
# 15  \n\n\nJ. Smith\n\n                        TE\n...
# 16  \n\n\nZ. Ertz\n\n                        TE\n ...
# 17  \n\n\nE. Ebron\n\n                        TE\n...
# 18  \n\n\nE. Engram\n\n                        TE\...
# 19  \n\n\nG. Everett\n\n                        TE...
# 20  \n\n\nH. Henry\n\n                        TE\n...
# 21  \n\n\nA. Trautman\n\n                        T...
# 22  \n\n\nA. Hooper\n\n                        TE\...
# 23  \n\n\nC. Kmet\n\n                        TE\n ...
# 24  \n\n\nB. Jarwin\n\n                        TE\...
#
#    \n                \n                                    Trend\n                \n                              \
# 0           \n                    —\n
# 1                                         \n\n -2\n\n
# 2                                          \n\n 1\n\n
# 3                                          \n\n 2\n\n
# 4                                         \n\n -2\n\n
# 5                                         \n\n -3\n\n
# 6                                         \n\n 20\n\n
# 7                                         \n\n -2\n\n
# 8                                         \n\n -8\n\n
# 9                                         \n\n -4\n\n
# 10                                        \n\n 14\n\n
# 11                                        \n\n -2\n\n
# 12                                        \n\n -8\n\n
# 13                                         \n\n 6\n\n
# 14                                       \n\n -25\n\n
# 15                                        \n\n 22\n\n
# 16                                        \n\n 16\n\n
# 17                                       \n\n -42\n\n
# 18                                        \n\n -8\n\n
# 19                                        \n\n 36\n\n
# 20                                       \n\n -24\n\n
# 21                                       \n\n -46\n\n
# 22                                        \n\n -3\n\n
# 23                                         \n\n 2\n\n
# 24                                       \n\n -12\n\n
#
#    \n                \n                                    Avg Pos\n                \n                              \
# 0       \n                    10.17\n
# 1       \n                    25.73\n
# 2       \n                    29.11\n
# 3       \n                    51.87\n
# 4       \n                    53.56\n
# 5       \n                    66.90\n
# 6       \n                    86.97\n
# 7       \n                    89.47\n
# 8      \n                    103.48\n
# 9      \n                    103.79\n
# 10     \n                    104.40\n
# 11     \n                    109.02\n
# 12     \n                    117.70\n
# 13     \n                    123.61\n
# 14     \n                    126.40\n
# 15     \n                    133.25\n
# 16     \n                    141.10\n
# 17     \n                    149.68\n
# 18     \n                    150.35\n
# 19     \n                    150.45\n
# 20     \n                    153.94\n
# 21     \n                    156.59\n
# 22     \n                    162.00\n
# 23     \n                    165.86\n
# 24     \n                    168.41\n
#
#    \n                \n                                    Hi/Lo\n                \n                              \
# 0        \n                    4/19\n
# 1       \n                    12/43\n
# 2       \n                    17/48\n
# 3       \n                    32/84\n
# 4       \n                    32/81\n
# 5      \n                    44/111\n
# 6      \n                    57/141\n
# 7      \n                    59/141\n
# 8      \n                    65/152\n
# 9      \n                    65/153\n
# 10     \n                    64/155\n
# 11     \n                    62/159\n
# 12     \n                    73/170\n
# 13     \n                    60/178\n
# 14     \n                    65/182\n
# 15     \n                    86/179\n
# 16     \n                    79/191\n
# 17     \n                    85/199\n
# 18     \n                    99/194\n
# 19    \n                    104/195\n
# 20     \n                    97/202\n
# 21     \n                    89/211\n
# 22    \n                    107/210\n
# 23    \n                    112/213\n
# 24    \n                    115/221\n
#
#    \n                \n                                    Pct\n                \n
# 0        \n                    99.4\n
# 1        \n                    99.5\n
# 2        \n                    99.5\n
# 3        \n                    99.3\n
# 4        \n                    99.6\n
# 5        \n                    96.5\n
# 6        \n                    91.1\n
# 7        \n                    91.1\n
# 8        \n                    88.2\n
# 9        \n                    87.5\n
# 10       \n                    88.3\n
# 11       \n                    86.0\n
# 12       \n                    78.6\n
# 13       \n                    79.3\n
# 14       \n                    72.5\n
# 15       \n                    73.5\n
# 16       \n                    63.1\n
# 17       \n                    46.2\n
# 18       \n                    51.0\n
# 19       \n                    49.9\n
# 20       \n                    44.3\n
# 21       \n                    30.0\n
# 22       \n                    35.1\n
# 23       \n                    26.4\n
# 24       \n                    21.4\n

# %%
df1 = df1.replace(r'\n',' ', regex=True)

# %%
df1
# Out:
#    \n                \n                                    Rank\n                \n                              \
# 0                                  8
# 1                                 23
# 2                                 25
# 3                                 53
# 4                                 55
# 5                                 66
# 6                                 79
# 7                                 85
# 8                                 98
# 9                                 99
# 10                               100
# 11                               104
# 12                               121
# 13                               126
# 14                               130
# 15                               142
# 16                               160
# 17                               176
# 18                               180
# 19                               181
# 20                               185
# 21                               193
# 22                               200
# 23                               212
# 24                               217
#
#    \n                \n                                    Player\n                \n                              \
# 0      T. Kelce                          TE       ...
# 1      G. Kittle                          TE      ...
# 2      D. Waller                          TE      ...
# 3      M. Andrews                          TE     ...
# 4      K. Pitts                          TE       ...
# 5      T. Hockenson                          TE   ...
# 6      L. Thomas                          TE      ...
# 7      N. Fant                          TE        ...
# 8      D. Goedert                          TE     ...
# 9      T. Higbee                          TE      ...
# 10     M. Gesicki                          TE     ...
# 11     R. Tonyan                          TE      ...
# 12     I. Smith                          TE       ...
# 13     R. Gronkowski                          TE  ...
# 14     J. Cook                          TE        ...
# 15     J. Smith                          TE       ...
# 16     Z. Ertz                          TE        ...
# 17     E. Ebron                          TE       ...
# 18     E. Engram                          TE      ...
# 19     G. Everett                          TE     ...
# 20     H. Henry                          TE       ...
# 21     A. Trautman                          TE    ...
# 22     A. Hooper                          TE      ...
# 23     C. Kmet                          TE        ...
# 24     B. Jarwin                          TE      ...
#
#    \n                \n                                    Trend\n                \n                              \
# 0                                  —
# 1                                                -2
# 2                                                 1
# 3                                                 2
# 4                                                -2
# 5                                                -3
# 6                                                20
# 7                                                -2
# 8                                                -8
# 9                                                -4
# 10                                               14
# 11                                               -2
# 12                                               -8
# 13                                                6
# 14                                              -25
# 15                                               22
# 16                                               16
# 17                                              -42
# 18                                               -8
# 19                                               36
# 20                                              -24
# 21                                              -46
# 22                                               -3
# 23                                                2
# 24                                              -12
#
#    \n                \n                                    Avg Pos\n                \n                              \
# 0                              10.17
# 1                              25.73
# 2                              29.11
# 3                              51.87
# 4                              53.56
# 5                              66.90
# 6                              86.97
# 7                              89.47
# 8                             103.48
# 9                             103.79
# 10                            104.40
# 11                            109.02
# 12                            117.70
# 13                            123.61
# 14                            126.40
# 15                            133.25
# 16                            141.10
# 17                            149.68
# 18                            150.35
# 19                            150.45
# 20                            153.94
# 21                            156.59
# 22                            162.00
# 23                            165.86
# 24                            168.41
#
#    \n                \n                                    Hi/Lo\n                \n                              \
# 0                               4/19
# 1                              12/43
# 2                              17/48
# 3                              32/84
# 4                              32/81
# 5                             44/111
# 6                             57/141
# 7                             59/141
# 8                             65/152
# 9                             65/153
# 10                            64/155
# 11                            62/159
# 12                            73/170
# 13                            60/178
# 14                            65/182
# 15                            86/179
# 16                            79/191
# 17                            85/199
# 18                            99/194
# 19                           104/195
# 20                            97/202
# 21                            89/211
# 22                           107/210
# 23                           112/213
# 24                           115/221
#
#    \n                \n                                    Pct\n                \n
# 0                               99.4
# 1                               99.5
# 2                               99.5
# 3                               99.3
# 4                               99.6
# 5                               96.5
# 6                               91.1
# 7                               91.1
# 8                               88.2
# 9                               87.5
# 10                              88.3
# 11                              86.0
# 12                              78.6
# 13                              79.3
# 14                              72.5
# 15                              73.5
# 16                              63.1
# 17                              46.2
# 18                              51.0
# 19                              49.9
# 20                              44.3
# 21                              30.0
# 22                              35.1
# 23                              26.4
# 24                              21.4

# %%
df1.to_csv('TEadpstats.csv',index=False)
